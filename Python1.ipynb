# %% [markdown]
# <a href="https://colab.research.google.com/github/mailnami-coder/python-basics/blob/main/Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Basics - Data Types, Variables, and Operators

# %% [markdown]
# 1. Python Data Types
#
# Numeric Types
#
#
# *   int (Integer)
# *   float (Floating-point)
# *   complex (Complex numbers)
#
# Text Type
#
# *   str (String)
#
# Boolean Type
#
# *  bool (True/False)

# %%
# Examples of different data types
integer_num = 42
float_num = 3.14
complex_num = 2 + 3j
text = "Hello, Python!"
is_python_fun = True

# Check types
print(f"Type of {integer_num}: {type(integer_num)}")
print(f"Type of {float_num}: {type(float_num)}")
print(f"Type of {complex_num}: {type(complex_num)}")
print(f"Type of {text}: {type(text)}")
print(f"Type of {is_python_fun}: {type(is_python_fun)}")
# Out:
# Type of 42: <class 'int'>
# Type of 3.14: <class 'float'>
# Type of (2+3j): <class 'complex'>
# Type of Hello, Python!: <class 'str'>
# Type of True: <class 'bool'>

# %% [markdown]
# 2. Variables
#
# Rules for Python variables:
#
# *   Must start with a letter or underscore
# *   Can contain letters, numbers, and underscores
# *   Case-sensitive
# *   Cannot use reserved keywords

# %%
# Variable assignment examples
name = "Alice"
age = 25
height = 1.75
_private_var = "secret"

# Multiple assignment
x, y, z = 1, 2, 3

print(f"Name: {name}")
print(f"Age: {age}")
print(f"Height: {height}")
print(f"x: {x}, y: {y}, z: {z}")
# Out:
# Name: Alice
# Age: 25
# Height: 1.75
# x: 1, y: 2, z: 3

# %% [markdown]
# 3. Operators
#
# Arithmetic Operators
#
# *   `+` (Addition)
# *   `-` (Subtraction)
# *   `*` (Multiplication)
# *   `/` (Division)
# *   `//` (Floor Division)
# *   `%` (Modulus)
# *   `**` (Exponentiation)

# %%
# Arithmetic operations
a = 10
b = 3

print(f"Addition: {a + b}")
print(f"Subtraction: {a - b}")
print(f"Multiplication: {a * b}")
print(f"Division: {a / b}")
print(f"Floor Division: {a // b}")
print(f"Modulus: {a % b}")
print(f"Exponentiation: {a ** b}")
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponentiation: 1000

# %%
# Exercise 1: Temperature Converter
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# Test the function
temp_c = 25
temp_f = celsius_to_fahrenheit(temp_c)
print(f"{temp_c}°C is equal to {temp_f}°F")
# Out:
# 25°C is equal to 77.0°F

# %%
# Exercise 2: Simple Interest Calculator
def calculate_simple_interest(principal, rate, time):
    return (principal * rate * time) / 100

# Test the function
p = 1000  # Principal amount
r = 5     # Rate of interest
t = 2     # Time in years

interest = calculate_simple_interest(p, r, t)
print(f"Simple Interest: ${interest}")
# Out:
# Simple Interest: $100.0
